# %% [markdown]
# # Applying Advanced Transformations (Core)

# %% [markdown]
# ## Task:
#
# - Your task is two-fold:
#
# 1. Clean the files and combine them into one final DataFrame.
#
#       - This dataframe should have the following columns:
#            - Hero (Just the name of the Hero)
#            - Publisher
#            - Gender
#            - Eye color
#            - Race
#            - Hair color
#            - Height (numeric)
#            - Skin color
#            - Alignment
#            - Weight (numeric)
#            - Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
#                 - Agility
#                 - Flight
#                 - Superspeed
#                 - etc.
#
#  Hint: There is a space in "100 kg" or "52.5 cm"
#
#
# 2. Use your combined DataFrame to answer the following questions.
#
#     - Compare the average weight of super powers who have Super Speed to those who do not.
#     - What is the average height of heroes for each publisher?

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import json

# %%
info = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vS1ZstYLwFgwhZnqDsPjtnlHYhJp_cmW55J8JD5mym0seRsaem3px7QBtuFF0LiI7z1PLCkVKAkdO7J/pub?output=csv')
powers = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSzdWOBaXOoz52vPmCFV5idNlDBohLY1Lsbc1IfZIZQ7cV_aNB2wYBfhF49uE1TaO1B5MQCGWiNrFfd/pub?output=csv')

# %%
info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
print(info.info())
print(powers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
# None

# %%
info['Hero|Publisher'].head(3)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# 2              Abin Sur|DC Comics
# Name: Hero|Publisher, dtype: object

# %%
info['Hero|Publisher'].str.split('|', expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
info[['Hero', 'Publisher']] = info['Hero|Publisher'].str.split('|', expand=True)
info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
info= info.drop(columns=['Hero|Publisher'])
info.head(3)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
# 2   Male        Ungaran      good    No Hair      blue        red
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}    Abin Sur          DC Comics

# %%
measure= info.loc[0, "Measurements"]
measure
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
measure= measure.replace("'", '"')
measure
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
fixed_measure= json.loads(measure)
print(type(fixed_measure))
fixed_measure
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
info['Measurements']= info['Measurements'].str.replace("'",'"')

# %%
info['Measurements']= info['Measurements'].apply(json.loads)
info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
ht_wt= info['Measurements'].apply(pd.Series)
ht_wt
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
info = pd.concat((info, ht_wt), axis = 1)
info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
info= info.drop(columns= ['Measurements'])
info.head(1)
# Out:
#   Gender   Race Alignment Hair color Eye color Skin color    Hero  \
# 0   Male  Human      good    No Hair    yellow    Unknown  A-Bomb
#
#        Publisher    Height    Weight
# 0  Marvel Comics  203.0 cm  441.0 kg

# %%
info['Height'].str.split(' ', expand=True)
# Out:
#          0   1
# 0    203.0  cm
# 1    191.0  cm
# 2    185.0  cm
# 3    203.0  cm
# 4    193.0  cm
# ..     ...  ..
# 458  183.0  cm
# 459  165.0  cm
# 460   66.0  cm
# 461  170.0  cm
# 462  185.0  cm
#
# [463 rows x 2 columns]

# %%
info[['Height(cm)', 'cm']] = info['Height'].str.split(' ', expand=True)
info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight Height(cm) Weight(kg)  \
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg      203.0   441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg      191.0    65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg      185.0    90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg      203.0   441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg      193.0   122.0 kg
#
#    cm
# 0  cm
# 1  cm
# 2  cm
# 3  cm
# 4  cm

# %%
info['Weight'].str.split(' ', expand=True)
# Out:
#          0   1
# 0    441.0  kg
# 1     65.0  kg
# 2     90.0  kg
# 3    441.0  kg
# 4    122.0  kg
# ..     ...  ..
# 458   83.0  kg
# 459   52.0  kg
# 460   17.0  kg
# 461   57.0  kg
# 462   81.0  kg
#
# [463 rows x 2 columns]

# %%
info[['Weight(kg)', 'kg']] = info['Weight'].str.split(' ', expand=True)
info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight Height(cm) Weight(kg)  \
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg      191.0       65.0
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg      185.0       90.0
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg      203.0      441.0
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg      193.0      122.0
#
#    cm  kg
# 0  cm  kg
# 1  cm  kg
# 2  cm  kg
# 3  cm  kg
# 4  cm  kg

# %%
info= info.drop(columns= ['Height', 'Weight', 'cm', 'kg'])
info.head(1)
# Out:
#   Gender   Race Alignment Hair color Eye color Skin color    Hero  \
# 0   Male  Human      good    No Hair    yellow    Unknown  A-Bomb
#
#        Publisher Height(cm) Weight(kg)
# 0  Marvel Comics      203.0      441.0

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height(cm)  463 non-null    object
#  9   Weight(kg)  463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
info = info.astype({'Height(cm)': float, 'Weight(kg)': float})
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height(cm)  463 non-null    float64
#  9   Weight(kg)  463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
powers.loc[1, 'Powers']
# Out:
# 'Accelerated Healing,Durability,Longevity,Super Strength,Stamina,Camouflage,Self-Sustenance'

# %%
powers['powers_split']= powers['Powers'].str.replace("'",'"')

# %%
powers['powers_split'].value_counts()
# Out:
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# Agility,Stealth,Marksmanship,Weapons Master,Stamina                                                                                                                                                                                                                  4
# Marksmanship                                                                                                                                                                                                                                                         4
# Teleportation                                                                                                                                                                                                                                                        4
#                                                                                                                                                                                                                                                                     ..
# Accelerated Healing,Flight,Telepathy,Energy Blasts,Teleportation,Telekinesis,Astral Projection,Psionic Powers,Mind Blast,Regeneration,Illusions,Resurrection                                                                                                         1
# Flight,Telepathy,Animal Oriented Powers,Gliding                                                                                                                                                                                                                      1
# Accelerated Healing,Durability,Energy Absorption,Flight,Super Strength,Telepathy,Energy Blasts,Size Changing,Super Speed,Darkforce Manipulation,Enhanced Senses,Phasing,Invulnerability,Self-Sustenance,Gravity Control,Energy Manipulation,Time Travel,Illusions    1
# Agility,Accelerated Healing,Super Strength,Super Speed,Animal Oriented Powers,Enhanced Senses,Jump,Reflexes,Natural Weapons                                                                                                                                          1
# Super Speed,Intangibility,Time Travel,Time Manipulation                                                                                                                                                                                                              1
# Name: powers_split, Length: 608, dtype: int64

# %%
exploded= powers.explode('powers_split')
exploded[['hero_names', 'Powers', 'powers_split']].head(20)
# Out:
#           hero_names                                             Powers  \
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# 5            Abraxas  Dimensional Awareness,Flight,Intelligence,Supe...
# 6      Absorbing Man  Cold Resistance,Durability,Energy Absorption,S...
# 7        Adam Monroe       Accelerated Healing,Immortality,Regeneration
# 8       Adam Strange  Durability,Stealth,Flight,Marksmanship,Weapons...
# 9          Agent Bob                                            Stealth
# 10        Agent Zero  Energy Absorption,Longevity,Super Strength,Ene...
# 11        Air-Walker  Flight,Super Strength,Super Speed,Self-Sustena...
# 12              Ajax  Agility,Super Strength,Super Speed,Heat Genera...
# 13        Alan Scott  Flight,Danger Sense,Intelligence,Telepathy,Ene...
# 14       Alex Mercer  Agility,Accelerated Healing,Stealth,Energy Abs...
# 15      Alex Woolsly                               Underwater breathing
# 16             Alien  Agility,Cold Resistance,Durability,Stealth,Sup...
# 17  Allan Quatermain                                       Marksmanship
# 18             Amazo  Agility,Lantern Power Ring,Durability,Flight,U...
# 19              Ammo                                     Weapons Master
#
#                                          powers_split
# 0          Agility,Super Strength,Stamina,Super Speed
# 1   Accelerated Healing,Durability,Longevity,Super...
# 2   Agility,Accelerated Healing,Cold Resistance,Du...
# 3                                  Lantern Power Ring
# 4   Accelerated Healing,Intelligence,Super Strengt...
# 5   Dimensional Awareness,Flight,Intelligence,Supe...
# 6   Cold Resistance,Durability,Energy Absorption,S...
# 7        Accelerated Healing,Immortality,Regeneration
# 8   Durability,Stealth,Flight,Marksmanship,Weapons...
# 9                                             Stealth
# 10  Energy Absorption,Longevity,Super Strength,Ene...
# 11  Flight,Super Strength,Super Speed,Self-Sustena...
# 12  Agility,Super Strength,Super Speed,Heat Genera...
# 13  Flight,Danger Sense,Intelligence,Telepathy,Ene...
# 14  Agility,Accelerated Healing,Stealth,Energy Abs...
# 15                               Underwater breathing
# 16  Agility,Cold Resistance,Durability,Stealth,Sup...
# 17                                       Marksmanship
# 18  Agility,Lantern Power Ring,Durability,Flight,U...
# 19                                     Weapons Master

# %%
merged= pd.merge(info, powers, left_on= 'Hero', right_on= 'hero_names', how= 'inner')
merged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height(cm)  Weight(kg)     hero_names  \
# 0         A-Bomb      Marvel Comics       203.0       441.0         A-Bomb
# 1     Abe Sapien  Dark Horse Comics       191.0        65.0     Abe Sapien
# 2       Abin Sur          DC Comics       185.0        90.0       Abin Sur
# 3    Abomination      Marvel Comics       203.0       441.0    Abomination
# 4  Absorbing Man      Marvel Comics       193.0       122.0  Absorbing Man
#
#                                               Powers  \
# 0  Accelerated Healing,Durability,Longevity,Super...
# 1  Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                 Lantern Power Ring
# 3  Accelerated Healing,Intelligence,Super Strengt...
# 4  Cold Resistance,Durability,Energy Absorption,S...
#
#                                         powers_split
# 0  Accelerated Healing,Durability,Longevity,Super...
# 1  Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                 Lantern Power Ring
# 3  Accelerated Healing,Intelligence,Super Strengt...
# 4  Cold Resistance,Durability,Energy Absorption,S...

# %% [markdown]
# ## Super Speed Weight
# - 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
avg_wt= merged['Weight(kg)'].mean()

# %%
avg_wt
# Out:
# 113.58963282937366

# %%
super_speed= merged[merged['Powers'].str.contains('Super Speed')]

# %%
avg_ss_wt= super_speed.mean()
avg_ss_wt
# Out:
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/438038298.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_ss_wt= super_speed.mean()
# Height(cm)    189.444444
# Weight(kg)    129.404040
# dtype: float64

# %%
no_speed= merged[merged['Powers'].str.contains('Super Speed') == False]
no_speed
# Out:
#      Gender            Race Alignment        Hair color Eye color Skin color  \
# 0      Male           Human      good           No Hair    yellow    Unknown
# 1      Male   Icthyo Sapien      good           No Hair      blue       blue
# 2      Male         Ungaran      good           No Hair      blue        red
# 4      Male           Human       bad           No Hair      blue    Unknown
# 6      Male           Human      good             Brown     brown    Unknown
# ..      ...             ...       ...               ...       ...        ...
# 456  Female  Mutant / Clone      good             Black     green    Unknown
# 457    Male         Unknown      good             Brown      blue    Unknown
# 458    Male           Human      good             Blond      blue    Unknown
# 459  Female           Human      good  Strawberry Blond      blue    Unknown
# 461  Female           Human      good             Black      blue    Unknown
#
#                 Hero          Publisher  Height(cm)  Weight(kg)  \
# 0             A-Bomb      Marvel Comics       203.0       441.0
# 1         Abe Sapien  Dark Horse Comics       191.0        65.0
# 2           Abin Sur          DC Comics       185.0        90.0
# 4      Absorbing Man      Marvel Comics       193.0       122.0
# 6          Agent Bob      Marvel Comics       178.0        81.0
# ..               ...                ...         ...         ...
# 456             X-23      Marvel Comics       155.0        50.0
# 457            X-Man      Marvel Comics       175.0        61.0
# 458     Yellowjacket      Marvel Comics       183.0        83.0
# 459  Yellowjacket II      Marvel Comics       165.0        52.0
# 461          Zatanna          DC Comics       170.0        57.0
#
#           hero_names                                             Powers  \
# 0             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 1         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 2           Abin Sur                                 Lantern Power Ring
# 4      Absorbing Man  Cold Resistance,Durability,Energy Absorption,S...
# 6          Agent Bob                                            Stealth
# ..               ...                                                ...
# 456             X-23  Agility,Accelerated Healing,Durability,Stealth...
# 457            X-Man  Flight,Telepathy,Astral Travel,Teleportation,T...
# 458     Yellowjacket               Size Changing,Animal Oriented Powers
# 459  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 461          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
#
#                                           powers_split
# 0    Accelerated Healing,Durability,Longevity,Super...
# 1    Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                   Lantern Power Ring
# 4    Cold Resistance,Durability,Energy Absorption,S...
# 6                                              Stealth
# ..                                                 ...
# 456  Agility,Accelerated Healing,Durability,Stealth...
# 457  Flight,Telepathy,Astral Travel,Teleportation,T...
# 458               Size Changing,Animal Oriented Powers
# 459                 Flight,Energy Blasts,Size Changing
# 461  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
#
# [265 rows x 13 columns]

# %%
avg_ns_wt= no_speed.mean()
avg_ns_wt
# Out:
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/2728794053.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_ns_wt= no_speed.mean()
# Height(cm)    186.376226
# Weight(kg)    101.773585
# dtype: float64

# %%
print(f'Average Super Speed Weight: {avg_ss_wt}')
print(f'Average Non-Super Speed Weigh: {avg_ns_wt}')
# Out:
# Average Super Speed Weight: Height(cm)    189.444444
# Weight(kg)    129.404040
# dtype: float64
# Average Non-Super Speed Weigh: Height(cm)    186.376226
# Weight(kg)    101.773585
# dtype: float64

# %% [markdown]
# - The average weight of heroes with super speed is 129.4 kg
# - The average weight of heroes without super speed is 101.7 kg

# %% [markdown]
# ## Average Publisher Hero Hts
# - 2. What is the average height of heroes for each publisher?

# %%
merged['Publisher'].unique()
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', 'DC Comics', 'Team Epic TV',
#        'George Lucas', 'Shueisha', 'Star Trek', 'Unknown', 'Image Comics'],
#       dtype=object)

# %%
marvel = merged[merged['Publisher'] == 'Marvel Comics'].mean()

darkhorse = merged[merged['Publisher'] == 'Dark Horse Comics'].mean()

dc = merged[merged['Publisher'] == 'DC Comics'].mean()

epic = merged[merged['Publisher'] == 'Team Epic TV'].mean()

gl= merged[merged['Publisher'] == 'George Lucas'].mean()

shue= merged[merged['Publisher'] == 'Shueisha'].mean()

trek= merged[merged['Publisher'] == 'Star Trek'].mean()

unknown = merged[merged['Publisher'] == 'Unknown'].mean()

image= merged[merged['Publisher'] == 'Image Comics'].mean()
# Out:
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   marvel = merged[merged['Publisher'] == 'Marvel Comics'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   darkhorse = merged[merged['Publisher'] == 'Dark Horse Comics'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dc = merged[merged['Publisher'] == 'DC Comics'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   epic = merged[merged['Publisher'] == 'Team Epic TV'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:9: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gl= merged[merged['Publisher'] == 'George Lucas'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   shue= merged[merged['Publisher'] == 'Shueisha'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   trek= merged[merged['Publisher'] == 'Star Trek'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   unknown = merged[merged['Publisher'] == 'Unknown'].mean()
# /var/folders/5z/rbhjbxt93x56vw5bldr0n_900000gn/T/ipykernel_15858/1100030273.py:17: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   image= merged[merged['Publisher'] == 'Image Comics'].mean()

# %%
print(f'Marvel Comics: {marvel}')
print(f'Dark Horse: {darkhorse}')
print(f'DC Comics: {dc}')
print(f'Epic TV: {epic}')
print(f'George Lucas: {gl}')
print(f'Shueisha: {shue}')
print(f'Star Trek: {trek}')
print(f'Unknown: {unknown}')
print(f'Image Comics: {image}')
# Out:
# Marvel Comics: Height(cm)    191.546128
# Weight(kg)    119.579125
# dtype: float64
# Dark Horse: Height(cm)    176.909091
# Weight(kg)    101.818182
# dtype: float64
# DC Comics: Height(cm)    181.923913
# Weight(kg)    104.188406
# dtype: float64
# Epic TV: Height(cm)    180.75
# Weight(kg)     72.00
# dtype: float64
# George Lucas: Height(cm)    159.6
# Weight(kg)     77.4
# dtype: float64
# Shueisha: Height(cm)    171.5
# Weight(kg)     64.5
# dtype: float64
# Star Trek: Height(cm)    181.5
# Weight(kg)     79.0
# dtype: float64
# Unknown: Height(cm)    178.0
# Weight(kg)     83.0
# dtype: float64
# Image Comics: Height(cm)    211.0
# Weight(kg)    405.0
# dtype: float64

# %% [markdown]
# - Marvel Comics
#     - 191.5 cm
# - Dark Horse
#     - 176.9 cm
# - DC Comics
#     - 181.9 cm
# - Epic TV
#     - 180.7 cm
# - George Lucas
#     - 159.6 cm
# - Shueisha
#     - 171.5 cm
# - Star Trek
#     - 181.5 cm
# - Unknown
#     - 178 cm
# - Image Comics
#     - 211 cm
